# %% [markdown]
# 2 / 2 ... 0
#
# 4 / 2 ... 0
#
# 6 / 2 ... 0
#
# ...
#
# 모든 짝수는 2로 나눴을 때, 나머지가 0이다.
#
# 3 / 2 ... 1
#
# 5 / 2 ... 1
#
# 7 / 2 ... 1
#
# ...
#
# 모든 홀수는 2로 나눴을 때, 나머지가 0이 아니다.

# %%
num = 4

# %%
check = "짝수" if num % 2 == 0 else "홀수"

# %%
check
# Out:
# '짝수'

# %%
num = 5

# %%
check = "짝수" if num % 2 == 0 else "홀수"

# %%
check
# Out:
# '홀수'

# %%
a = input()
b = int(a.split()[0])
c = int(a.split()[1])
d = int(a.split()[2])

# %% [markdown]
# 18 7 -5
#
# b = 18
#
# c = 7
#
# d = -5

# %%
min = b

# %%
min = min if min < c else c

# %%
min = min if min < d else d

# %%
print(min)
# Out:
# 18
